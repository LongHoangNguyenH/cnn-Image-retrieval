# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os 
import sys 
ROOT_DIR = '/content/drive/MyDrive/20522176_20521568_20521563_20521583' 
os.chdir (ROOT_DIR) 
sys.path.append(ROOT_DIR)

# %%
# !python3 -m cirtorch.examples.test --gpu-id '0' --network-path 'retrievalSfM120k-vgg16-gem' --datasets 'oxford5k' --whitening 'retrieval-SfM-120k' --multiscale '[1, 1/2**(1/2), 1/2]'
# Out:
# >> Created symbolic link from retrieval-SfM-120k/ims to retrieval-SfM-30k/ims
# >> DB file retrieval-SfM-120k.pkl does not exist. Downloading...
# --2023-02-08 01:17:20--  http://cmp.felk.cvut.cz/cnnimageretrieval/data/train/dbs/retrieval-SfM-120k.pkl
# Resolving cmp.felk.cvut.cz (cmp.felk.cvut.cz)... 147.32.84.2
# Connecting to cmp.felk.cvut.cz (cmp.felk.cvut.cz)|147.32.84.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5511478 (5.3M)
# Saving to: ‘/content/drive/MyDrive/cnnimageretrieval-pytorch-master/data/train/retrieval-SfM-120k/retrieval-SfM-120k.pkl’
#
# /content/drive/MyDr 100%[===================>]   5.26M  3.25MB/s    in 1.6s
#
# 2023-02-08 01:17:23 (3.25 MB/s) - ‘/content/drive/MyDrive/cnnimageretrieval-pytorch-master/data/train/retrieval-SfM-120k/retrieval-SfM-120k.pkl’ saved [5511478/5511478]
#
# >> DB file retrieval-SfM-120k-whiten.pkl does not exist. Downloading...
# ...

# %%
# !python3 -m cirtorch.examples.test --gpu-id '0' --network-path 'retrievalSfM120k-resnet101-gem' --datasets 'oxford5k' --whitening 'retrieval-SfM-120k' --multiscale '[1, 1/2**(1/2), 1/2]'
# Out:
# >> Loading network:
# >>>> 'retrievalSfM120k-resnet101-gem'
# Downloading: "http://cmp.felk.cvut.cz/cnnimageretrieval/data/networks/retrieval-SfM-120k/retrievalSfM120k-resnet101-gem-b80fb85.pth" to /content/drive/MyDrive/cnnimageretrieval-pytorch-master/data/networks/retrievalSfM120k-resnet101-gem-b80fb85.pth
# 100% 258M/258M [00:20<00:00, 13.3MB/s]
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# >>>> loaded network:
#   (meta): dict(
#      architecture: resnet101
#      local_whitening: False
#      pooling: gem
# ...

# %%
# !python3 -m cirtorch.examples.test --gpu-id '0' --network-path 'retrievalSfM120k-vgg16-gem' --datasets 'paris6k' --whitening 'retrieval-SfM-120k' --multiscale '[1, 1/2**(1/2), 1/2]'
# Out:
# >> Loading network:
# >>>> 'retrievalSfM120k-vgg16-gem'
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# >>>> loaded network:
#   (meta): dict(
#      architecture: vgg16
#      local_whitening: False
#      pooling: gem
#      regional: False
#      whitening: False
#      outputdim: 512
#      mean: [0.485, 0.456, 0.406]
#      std: [0.229, 0.224, 0.225]
#   )
#
# >> Set-up multiscale:
# >>>> ms: [1, 0.7071067811865475, 0.5]
# >>>> msp: 2.9208486080169678
# >> retrieval-SfM-120k: Whitening is precomputed, loading it...
# ...

# %%
# !python3 -m cirtorch.examples.test --gpu-id '0' --network-path 'retrievalSfM120k-resnet101-gem' --datasets 'paris6k' --whitening 'retrieval-SfM-120k' --multiscale '[1, 1/2**(1/2), 1/2]'
# Out:
# >> Loading network:
# >>>> 'retrievalSfM120k-resnet101-gem'
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# >>>> loaded network:
#   (meta): dict(
#      architecture: resnet101
#      local_whitening: False
#      pooling: gem
#      regional: False
#      whitening: False
#      outputdim: 2048
#      mean: [0.485, 0.456, 0.406]
#      std: [0.229, 0.224, 0.225]
#   )
#
# >> Set-up multiscale:
# >>>> ms: [1, 0.7071067811865475, 0.5]
# >>>> msp: 2.9032764434814453
# ...
